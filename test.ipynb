# %% [markdown]
# <h1><span style="color: red">Bioinformatics</span></h1><br>
# <details><summary>Tutorial for editing</summary>
# <p><b>粗體</b>用"b"<br>
# <i>斜體</i>用"i"<br>
# <u>下底線</u>用"u"<br>
# <b></b>用"b"<br>
# 分隔線用 ***或---<br>
#
# ***
#
# <span style="color: blue">藍色字</span><br>
# </details>

# %% [markdown]
# <h2>Import necessary libraries</h2>

# %%
#Run this cell to import necessary libraries
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h2>awe</h2>

# %%
# Generate x values from 0 to 10
x = np.linspace(0, 10, 100)

# Define a linear relationship: y = 2x + 1
y = 2 * x + 1

# Create the plot
mpl.rcParams['font.family'] = 'Arial'
plt.plot(x, y, label='y = 2x + 1')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Relationship Plot')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()
