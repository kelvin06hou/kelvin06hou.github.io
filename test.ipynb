# %% [markdown]
# <h1>Bioinformatics</h1>
# <details><summary>Hello</summary>
# <p>Enter your answer here: <input></input></p></details>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Hello World")
# Out:
# Hello World
